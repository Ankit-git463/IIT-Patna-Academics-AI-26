# %%
import random
import math
import time

def initial_state():
    numbers = random.sample(range(9), 9)
    return [numbers[i:i+3] for i in range(0, 9, 3)]

def generate_neighbor(state):
    new_state = [row[:] for row in state]
    i, j = random.randint(0, 2), random.randint(0, 2)
    x, y = random.randint(0, 2), random.randint(0, 2)
    new_state[i][j], new_state[x][y] = new_state[x][y], new_state[i][j]
    return new_state

def objective_function2(state):
    goal_state = [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
    distance = 0
    for i in range(3):
        for j in range(3):
            value = state[i][j]
            if value != 0:
                goal_row, goal_col = (value - 1) // 3, (value - 1) % 3
                distance += abs(goal_row - i) + abs(goal_col - j)
    return distance

def objective_function1(state):
    goal_state = [[1, 2, 3], [4, 5, 6], [7, 8, 0]]
    displaced = 0
    for i in range(3):
        for j in range(3):
            if state[i][j] != 0 and state[i][j] != goal_state[i][j]:
                displaced += 1
    return displaced

def acceptance_probability(deltaE, temperature):
    if deltaE < 0:
        return 1.0
    return math.exp(-deltaE / temperature)

def simulated_annealing1():
    current_state = initial_state()
    print("Initial State:")
    for row in current_state:
        print(row)
    print()
    temperature = 1000
    cooling_rate = 0.99
    max_iterations = 10000
    consecutive_worse_moves = 0
    for i in range(max_iterations):
        if( objective_function1( current_state ) == 0):
            return current_state, i
        neighbor_state = generate_neighbor(current_state)
        deltaE = objective_function1(neighbor_state) - objective_function1(current_state)
        if deltaE > 0:
            consecutive_worse_moves += 1
            if consecutive_worse_moves > 100:  # Threshold for random walk detection
                print("Random walk scenario detected at iteration:", i+1)
                break
        else:
            consecutive_worse_moves = 0
        if acceptance_probability(deltaE, temperature) > random.random():
            current_state = neighbor_state
            print("Iteration", i+1, "Temperature:", temperature)
            for row in current_state:
                print(row)
            print("Objective function value:",objective_function1(current_state))
            print()
        temperature *= cooling_rate
    return current_state, 10000

def simulated_annealing2():
    current_state = initial_state()
    print("Initial State:")
    for row in current_state:
        print(row)
    print()
    temperature = 1000
    cooling_rate = 0.99
    max_iterations = 1000
    consecutive_worse_moves = 0
    for i in range(max_iterations):
        if( objective_function2( current_state ) == 0):
            return current_state, i
        neighbor_state = generate_neighbor(current_state)
        deltaE = objective_function2(neighbor_state) - objective_function2(current_state)
        if deltaE > 0:
            consecutive_worse_moves += 1
            if consecutive_worse_moves > 100:  # Threshold for random walk detection
                print("Random walk scenario detected at iteration:", i+1)
                break
        else:
            consecutive_worse_moves = 0
        if acceptance_probability(deltaE, temperature) > random.random():
            current_state = neighbor_state
            print("Iteration", i+1, "Temperature:", temperature)
            for row in current_state:
                print(row)
            print("Objective function value:", objective_function2(current_state))
            print()

        temperature *= cooling_rate
    return current_state, 10000

def simulated_annealing3():
    current_state = initial_state()
    print("Initial State:")
    for row in current_state:
        print(row)
    print()
    temperature = 1000
    cooling_rate = 0.99
    max_iterations = 1000
    consecutive_worse_moves = 0
    x=10000
    for i in range(max_iterations):
        if( objective_function2( current_state )  + objective_function1( current_state ) ==0):
            return current_state, i
        neighbor_state = generate_neighbor(current_state)
        deltaE = objective_function2(neighbor_state) + objective_function1(neighbor_state) - objective_function2(current_state) - objective_function1(current_state)
        if deltaE > 0:
            consecutive_worse_moves += 1
            if consecutive_worse_moves > 100:  # Threshold for random walk detection
                print("Random walk scenario detected at iteration:", i+1)
                x=i
                break
        else:
            consecutive_worse_moves = 0
        if acceptance_probability(deltaE, temperature) > random.random():
            current_state = neighbor_state
            print("Iteration", i+1, "Temperature:", temperature)
            for row in current_state:
                print(row)
            print("Objective function value:", objective_function2(current_state) + objective_function1(current_state))
            print()
        temperature *= cooling_rate
    return current_state, x

def print_values(g, t, s):
    print("Heuristic: ", g)
    print("Time: ", t)
    print("States Explored: ", s)
    print("Temperature Chosen: 1000")
    print("Cooling Rate: 0.99")

begin = time.time()
solution, s = simulated_annealing1()
end = time.time()


print("Final Solution:")
for row in solution:
    print(row)
print("Objective function value:", objective_function1(solution))

print_values("Misplaced Tiles",end-begin,s)

print("_____----------------------------__________------_____--_--____-_-__---_-_")


print("Manhatten Distance Heuristic")

begin = time.time()
solution, s = simulated_annealing2()
end = time.time()

print("Final Solution:")
for row in solution:
    print(row)
print("Objective function value:", objective_function2(solution))

print_values("Manhatten Tiles",end-begin,s)


print("_____----------------------------__________------_____--_--____-_-__---_-_")


print("Manhatten Distance Heuristic + Misplaced tiles")

begin = time.time()
solution, s = simulated_annealing2()
end = time.time()

print("Final Solution:")
for row in solution:
    print(row)
print("Objective function value:", objective_function2(solution) + objective_function1(solution))

print_values("Manhatten Tiles + Misplaced Tiles",end-begin,s)
# Out:
# Streaming output truncated to the last 5000 lines.
# [1, 3, 6]
# [5, 8, 2]
# [0, 7, 4]
# Objective function value: 10
#
# Iteration 515 Temperature: 5.7080796309672595
# [1, 3, 8]
# [5, 6, 2]
# [0, 7, 4]
# Objective function value: 12
#
# Iteration 516 Temperature: 5.650998834657587
# [1, 3, 8]
# [5, 6, 2]
# [0, 7, 4]
# Objective function value: 12
#
# Iteration 517 Temperature: 5.594488846311011
# [1, 3, 8]
# [5, 6, 2]
# [4, 7, 0]
# Objective function value: 10
#
# Iteration 518 Temperature: 5.5385439578479
# [1, 3, 8]
# [5, 0, 2]
# [4, 7, 6]
# Objective function value: 10
#
# Iteration 519 Temperature: 5.483158518269422
# [1, 3, 8]
# [6, 0, 2]
# [4, 7, 5]
# Objective function value: 12
#
# Iteration 521 Temperature: 5.3740436637558595
# [1, 3, 4]
# [6, 0, 2]
# [8, 7, 5]
# Objective function value: 12
#
# Iteration 522 Temperature: 5.320303227118301
# [1, 4, 3]
# [6, 0, 2]
# [8, 7, 5]
# Objective function value: 10
#
# Iteration 524 Temperature: 5.214429192898647
# [1, 4, 3]
# [6, 0, 2]
# [8, 7, 5]
# Objective function value: 10
#
# Iteration 525 Temperature: 5.16228490096966
# [1, 4, 3]
# [6, 0, 2]
# [7, 8, 5]
# Objective function value: 8
#
# Iteration 528 Temperature: 5.00895987712596
# [1, 4, 3]
# [6, 0, 2]
# [7, 8, 5]
# Objective function value: 8
#
# Iteration 530 Temperature: 4.909281575571153
# [1, 4, 3]
# [6, 0, 7]
# [2, 8, 5]
# Objective function value: 12
#
# Iteration 531 Temperature: 4.860188759815442
# [1, 4, 3]
# [6, 0, 5]
# [2, 8, 7]
# Objective function value: 10
#
# Iteration 532 Temperature: 4.811586872217287
# [1, 4, 3]
# [6, 2, 5]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 533 Temperature: 4.763471003495114
# [1, 4, 3]
# [6, 5, 2]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 534 Temperature: 4.715836293460163
# [1, 4, 3]
# [6, 5, 8]
# [0, 2, 7]
# Objective function value: 10
#
# Iteration 535 Temperature: 4.668677930525561
# [1, 4, 3]
# [6, 2, 8]
# [0, 5, 7]
# Objective function value: 10
#
# Iteration 537 Temperature: 4.575771239708103
# [1, 4, 3]
# [6, 8, 2]
# [0, 5, 7]
# Objective function value: 10
#
# Iteration 538 Temperature: 4.530013527311022
# [4, 1, 3]
# [6, 8, 2]
# [0, 5, 7]
# Objective function value: 10
#
# Iteration 539 Temperature: 4.484713392037912
# [6, 1, 3]
# [4, 8, 2]
# [0, 5, 7]
# Objective function value: 10
#
# Iteration 540 Temperature: 4.439866258117532
# [6, 1, 3]
# [4, 8, 5]
# [0, 2, 7]
# Objective function value: 10
#
# Iteration 541 Temperature: 4.395467595536357
# [6, 4, 3]
# [1, 8, 5]
# [0, 2, 7]
# Objective function value: 12
#
# Iteration 542 Temperature: 4.351512919580993
# [6, 4, 3]
# [1, 8, 5]
# [0, 2, 7]
# Objective function value: 12
#
# Iteration 543 Temperature: 4.307997790385183
# [6, 4, 3]
# [2, 8, 5]
# [0, 1, 7]
# Objective function value: 14
#
# Iteration 544 Temperature: 4.264917812481332
# [3, 4, 6]
# [2, 8, 5]
# [0, 1, 7]
# Objective function value: 14
#
# Iteration 545 Temperature: 4.222268634356518
# [3, 1, 6]
# [2, 8, 5]
# [0, 4, 7]
# Objective function value: 12
#
# Iteration 546 Temperature: 4.180045948012953
# [2, 1, 6]
# [3, 8, 5]
# [0, 4, 7]
# Objective function value: 12
#
# Iteration 547 Temperature: 4.1382454885328235
# [2, 1, 0]
# [3, 8, 5]
# [6, 4, 7]
# Objective function value: 14
#
# Iteration 548 Temperature: 4.096863033647495
# [2, 5, 0]
# [3, 8, 1]
# [6, 4, 7]
# Objective function value: 16
#
# Iteration 549 Temperature: 4.0558944033110205
# [2, 5, 4]
# [3, 8, 1]
# [6, 0, 7]
# Objective function value: 17
#
# Iteration 550 Temperature: 4.01533545927791
# [2, 5, 8]
# [3, 4, 1]
# [6, 0, 7]
# Objective function value: 17
#
# Iteration 551 Temperature: 3.975182104685131
# [2, 5, 8]
# [3, 4, 1]
# [6, 0, 7]
# Objective function value: 17
#
# Iteration 552 Temperature: 3.9354302836382797
# [2, 4, 8]
# [3, 5, 1]
# [6, 0, 7]
# Objective function value: 17
#
# Iteration 553 Temperature: 3.8960759808018968
# [3, 4, 8]
# [2, 5, 1]
# [6, 0, 7]
# Objective function value: 17
#
# Iteration 554 Temperature: 3.8571152209938777
# [3, 4, 2]
# [8, 5, 1]
# [6, 0, 7]
# Objective function value: 15
#
# Iteration 556 Temperature: 3.7803586280960992
# [3, 4, 2]
# [8, 5, 1]
# [0, 6, 7]
# Objective function value: 14
#
# Iteration 557 Temperature: 3.7425550418151383
# [3, 4, 2]
# [8, 5, 1]
# [0, 6, 7]
# Objective function value: 14
#
# Iteration 558 Temperature: 3.705129491396987
# [3, 4, 2]
# [0, 5, 1]
# [8, 6, 7]
# Objective function value: 13
#
# Iteration 559 Temperature: 3.668078196483017
# [3, 7, 2]
# [0, 5, 1]
# [8, 6, 4]
# Objective function value: 15
#
# Iteration 560 Temperature: 3.6313974145181867
# [3, 4, 2]
# [0, 5, 1]
# [8, 6, 7]
# Objective function value: 13
#
# Iteration 561 Temperature: 3.5950834403730045
# [3, 5, 2]
# [0, 4, 1]
# [8, 6, 7]
# Objective function value: 13
#
# Iteration 562 Temperature: 3.5591326059692743
# [3, 4, 2]
# [0, 5, 1]
# [8, 6, 7]
# Objective function value: 13
#
# Iteration 563 Temperature: 3.5235412799095815
# [3, 4, 2]
# [0, 5, 8]
# [1, 6, 7]
# Objective function value: 13
#
# Iteration 564 Temperature: 3.4883058671104856
# [3, 4, 2]
# [0, 5, 8]
# [1, 6, 7]
# Objective function value: 13
#
# Iteration 565 Temperature: 3.4534228084393805
# [3, 4, 2]
# [0, 5, 8]
# [1, 6, 7]
# Objective function value: 13
#
# Iteration 566 Temperature: 3.4188885803549867
# [3, 4, 2]
# [0, 5, 8]
# [1, 6, 7]
# Objective function value: 13
#
# Iteration 567 Temperature: 3.3846996945514367
# [6, 4, 2]
# [0, 5, 8]
# [1, 3, 7]
# Objective function value: 15
#
# Iteration 568 Temperature: 3.3508526976059225
# [6, 4, 8]
# [0, 5, 2]
# [1, 3, 7]
# Objective function value: 17
#
# Iteration 569 Temperature: 3.3173441706298634
# [6, 4, 0]
# [8, 5, 2]
# [1, 3, 7]
# Objective function value: 16
#
# Iteration 570 Temperature: 3.2841707289235647
# [6, 4, 0]
# [8, 5, 2]
# [1, 3, 7]
# Objective function value: 16
#
# Iteration 571 Temperature: 3.251329021634329
# [6, 4, 0]
# [8, 5, 2]
# [1, 3, 7]
# Objective function value: 16
#
# Iteration 572 Temperature: 3.218815731417986
# [6, 1, 0]
# [8, 5, 2]
# [4, 3, 7]
# Objective function value: 14
#
# Iteration 573 Temperature: 3.186627574103806
# [4, 1, 0]
# [8, 5, 2]
# [6, 3, 7]
# Objective function value: 14
#
# Iteration 575 Temperature: 3.1232136853791403
# [4, 1, 0]
# [8, 3, 2]
# [6, 5, 7]
# Objective function value: 14
#
# Iteration 576 Temperature: 3.091981548525349
# [4, 1, 0]
# [8, 3, 2]
# [6, 5, 7]
# Objective function value: 14
#
# Iteration 577 Temperature: 3.0610617330400953
# [7, 1, 0]
# [8, 3, 2]
# [6, 5, 4]
# Objective function value: 16
#
# Iteration 578 Temperature: 3.0304511157096945
# [7, 1, 0]
# [8, 3, 2]
# [4, 5, 6]
# Objective function value: 12
#
# Iteration 579 Temperature: 3.0001466045525977
# [7, 3, 0]
# [8, 1, 2]
# [4, 5, 6]
# Objective function value: 12
#
# Iteration 580 Temperature: 2.9701451385070716
# [8, 3, 0]
# [7, 1, 2]
# [4, 5, 6]
# Objective function value: 12
#
# Iteration 581 Temperature: 2.9404436871220008
# [0, 3, 8]
# [7, 1, 2]
# [4, 5, 6]
# Objective function value: 12
#
# Iteration 582 Temperature: 2.9110392502507807
# [0, 3, 8]
# [7, 1, 5]
# [4, 2, 6]
# Objective function value: 12
#
# Iteration 583 Temperature: 2.8819288577482727
# [0, 3, 8]
# [2, 1, 5]
# [4, 7, 6]
# Objective function value: 12
#
# Iteration 584 Temperature: 2.85310956917079
# [3, 0, 8]
# [2, 1, 5]
# [4, 7, 6]
# Objective function value: 13
#
# Iteration 585 Temperature: 2.824578473479082
# [3, 0, 8]
# [1, 2, 5]
# [4, 7, 6]
# Objective function value: 11
#
# Iteration 587 Temperature: 2.768369361856848
# [3, 5, 8]
# [1, 2, 0]
# [4, 7, 6]
# Objective function value: 11
#
# Iteration 588 Temperature: 2.7406856682382794
# [2, 5, 8]
# [1, 3, 0]
# [4, 7, 6]
# Objective function value: 11
#
# Iteration 590 Temperature: 2.6861460234403376
# [2, 5, 6]
# [1, 3, 0]
# [4, 7, 8]
# Objective function value: 9
#
# Iteration 591 Temperature: 2.6592845632059343
# [2, 4, 6]
# [1, 3, 0]
# [5, 7, 8]
# Objective function value: 11
#
# Iteration 593 Temperature: 2.606364800398136
# [2, 4, 6]
# [1, 3, 7]
# [5, 0, 8]
# Objective function value: 13
#
# Iteration 595 Temperature: 2.554498140870213
# [2, 3, 6]
# [1, 4, 7]
# [5, 0, 8]
# Objective function value: 11
#
# Iteration 596 Temperature: 2.5289531594615107
# [2, 6, 3]
# [1, 4, 7]
# [5, 0, 8]
# Objective function value: 11
#
# Iteration 597 Temperature: 2.5036636278668953
# [2, 6, 3]
# [1, 4, 8]
# [5, 0, 7]
# Objective function value: 11
#
# Iteration 598 Temperature: 2.4786269915882264
# [2, 6, 3]
# [8, 4, 1]
# [5, 0, 7]
# Objective function value: 13
#
# Iteration 599 Temperature: 2.453840721672344
# [2, 6, 3]
# [8, 4, 1]
# [5, 0, 7]
# Objective function value: 13
#
# Iteration 600 Temperature: 2.4293023144556205
# [2, 6, 3]
# [8, 4, 1]
# [5, 0, 7]
# Objective function value: 13
#
# Iteration 601 Temperature: 2.4050092913110643
# [2, 5, 3]
# [8, 4, 1]
# [6, 0, 7]
# Objective function value: 13
#
# Iteration 602 Temperature: 2.380959198397954
# [1, 5, 3]
# [8, 4, 2]
# [6, 0, 7]
# Objective function value: 11
#
# Iteration 603 Temperature: 2.3571496064139743
# [1, 0, 3]
# [8, 4, 2]
# [6, 5, 7]
# Objective function value: 11
#
# Iteration 604 Temperature: 2.3335781103498348
# [1, 0, 3]
# [8, 4, 5]
# [6, 2, 7]
# Objective function value: 11
#
# Iteration 606 Temperature: 2.287139905953873
# [1, 3, 0]
# [8, 4, 5]
# [6, 2, 7]
# Objective function value: 12
#
# Iteration 608 Temperature: 2.2416258218253913
# [1, 3, 6]
# [8, 4, 5]
# [0, 2, 7]
# Objective function value: 10
#
# Iteration 609 Temperature: 2.219209563607137
# [3, 1, 6]
# [8, 4, 5]
# [0, 2, 7]
# Objective function value: 12
#
# Iteration 610 Temperature: 2.1970174679710657
# [6, 1, 3]
# [8, 4, 5]
# [0, 2, 7]
# Objective function value: 12
#
# Iteration 612 Temperature: 2.1532968203584413
# [7, 1, 3]
# [8, 4, 5]
# [0, 2, 6]
# Objective function value: 10
#
# Iteration 613 Temperature: 2.1317638521548568
# [7, 8, 3]
# [1, 4, 5]
# [0, 2, 6]
# Objective function value: 10
#
# Iteration 615 Temperature: 2.089341751496975
# [7, 8, 3]
# [2, 4, 5]
# [0, 1, 6]
# Objective function value: 12
#
# Iteration 616 Temperature: 2.0684483339820052
# [7, 8, 3]
# [6, 4, 5]
# [0, 1, 2]
# Objective function value: 14
#
# Iteration 618 Temperature: 2.0272862121357633
# [7, 8, 3]
# [0, 4, 5]
# [6, 1, 2]
# Objective function value: 15
#
# Iteration 619 Temperature: 2.0070133500144056
# [1, 8, 3]
# [0, 4, 5]
# [6, 7, 2]
# Objective function value: 11
#
# Iteration 621 Temperature: 1.9670737843491188
# [1, 8, 3]
# [0, 4, 6]
# [5, 7, 2]
# Objective function value: 9
#
# Iteration 622 Temperature: 1.9474030465056276
# [1, 8, 3]
# [0, 4, 6]
# [7, 5, 2]
# Objective function value: 7
#
# Iteration 623 Temperature: 1.9279290160405713
# [1, 8, 3]
# [0, 4, 2]
# [7, 5, 6]
# Objective function value: 7
#
# Iteration 625 Temperature: 1.889563228621364
# [1, 8, 3]
# [0, 4, 6]
# [7, 5, 2]
# Objective function value: 7
#
# Iteration 626 Temperature: 1.8706675963351502
# [1, 8, 3]
# [0, 4, 6]
# [7, 5, 2]
# Objective function value: 7
#
# Iteration 627 Temperature: 1.8519609203717986
# [1, 5, 3]
# [0, 4, 6]
# [7, 8, 2]
# Objective function value: 5
#
# Iteration 628 Temperature: 1.8334413111680805
# [1, 5, 3]
# [4, 0, 6]
# [7, 8, 2]
# Objective function value: 4
#
# Iteration 631 Temperature: 1.7789862707850774
# [1, 5, 0]
# [4, 3, 6]
# [7, 8, 2]
# Objective function value: 6
#
# Iteration 632 Temperature: 1.7611964080772267
# [0, 5, 1]
# [4, 3, 6]
# [7, 8, 2]
# Objective function value: 8
#
# Iteration 633 Temperature: 1.7435844439964543
# [0, 5, 1]
# [4, 3, 2]
# [7, 8, 6]
# Objective function value: 8
#
# Iteration 634 Temperature: 1.7261485995564898
# [0, 5, 1]
# [4, 2, 3]
# [7, 8, 6]
# Objective function value: 6
#
# Iteration 636 Temperature: 1.6917982424253157
# [0, 2, 1]
# [4, 5, 3]
# [7, 8, 6]
# Objective function value: 4
#
# Iteration 638 Temperature: 1.658131457401052
# [0, 2, 1]
# [4, 5, 3]
# [7, 8, 6]
# Objective function value: 4
#
# Iteration 639 Temperature: 1.6415501428270414
# [0, 2, 1]
# [4, 6, 3]
# [7, 8, 5]
# Objective function value: 6
#
# Iteration 642 Temperature: 1.5927944620349352
# [0, 1, 2]
# [4, 6, 3]
# [7, 8, 5]
# Objective function value: 6
#
# Iteration 643 Temperature: 1.576866517414586
# [1, 0, 2]
# [4, 6, 3]
# [7, 8, 5]
# Objective function value: 5
#
# Iteration 644 Temperature: 1.5610978522404402
# [1, 0, 2]
# [4, 6, 3]
# [7, 8, 5]
# Objective function value: 5
#
# Iteration 645 Temperature: 1.5454868737180358
# [1, 4, 2]
# [0, 6, 3]
# [7, 8, 5]
# Objective function value: 7
#
# Iteration 647 Temperature: 1.514731684931047
# [1, 4, 2]
# [0, 6, 3]
# [7, 8, 5]
# Objective function value: 7
#
# Iteration 648 Temperature: 1.4995843680817365
# [1, 4, 2]
# [5, 6, 3]
# [7, 8, 0]
# Objective function value: 6
#
# Iteration 653 Temperature: 1.4260898130313107
# [1, 4, 2]
# [5, 0, 3]
# [7, 8, 6]
# Objective function value: 6
#
# Iteration 654 Temperature: 1.4118289149009975
# [1, 4, 3]
# [5, 0, 2]
# [7, 8, 6]
# Objective function value: 6
#
# Iteration 659 Temperature: 1.3426352502319625
# [4, 1, 3]
# [5, 0, 2]
# [7, 8, 6]
# Objective function value: 6
#
# Iteration 661 Temperature: 1.3159168087523463
# [4, 1, 3]
# [7, 0, 2]
# [5, 8, 6]
# Objective function value: 8
#
# Iteration 662 Temperature: 1.302757640664823
# [4, 1, 3]
# [7, 0, 2]
# [6, 8, 5]
# Objective function value: 10
#
# Iteration 663 Temperature: 1.2897300642581746
# [8, 1, 3]
# [7, 0, 2]
# [6, 4, 5]
# Objective function value: 14
#
# Iteration 665 Temperature: 1.264064435979437
# [8, 1, 3]
# [7, 0, 2]
# [6, 4, 5]
# Objective function value: 14
#
# Iteration 666 Temperature: 1.2514237916196427
# [4, 1, 3]
# [7, 0, 2]
# [6, 8, 5]
# Objective function value: 10
#
# Iteration 667 Temperature: 1.2389095537034462
# [4, 1, 3]
# [7, 6, 2]
# [0, 8, 5]
# Objective function value: 8
#
# Iteration 671 Temperature: 1.1900915740384113
# [7, 1, 3]
# [4, 6, 2]
# [0, 8, 5]
# Objective function value: 8
#
# Iteration 672 Temperature: 1.178190658298027
# [5, 1, 3]
# [4, 6, 2]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 673 Temperature: 1.1664087517150468
# [5, 1, 3]
# [4, 6, 2]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 674 Temperature: 1.1547446641978962
# [5, 1, 3]
# [4, 6, 2]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 678 Temperature: 1.109243116997289
# [5, 1, 6]
# [4, 3, 2]
# [0, 8, 7]
# Objective function value: 10
#
# Iteration 680 Temperature: 1.0871691789690427
# [5, 1, 6]
# [4, 3, 2]
# [0, 8, 7]
# Objective function value: 10
#
# Iteration 684 Temperature: 1.0443303755126385
# [4, 1, 6]
# [5, 3, 2]
# [0, 8, 7]
# Objective function value: 10
#
# Iteration 689 Temperature: 0.9931477959208499
# [4, 1, 6]
# [5, 7, 2]
# [0, 8, 3]
# Objective function value: 10
#
# Iteration 690 Temperature: 0.9832163179616414
# [4, 1, 6]
# [5, 7, 2]
# [0, 8, 3]
# Objective function value: 10
#
# Iteration 693 Temperature: 0.9540138101018626
# [4, 1, 6]
# [5, 2, 7]
# [0, 8, 3]
# Objective function value: 10
#
# Iteration 694 Temperature: 0.944473672000844
# [5, 1, 6]
# [4, 2, 7]
# [0, 8, 3]
# Objective function value: 10
#
# Iteration 695 Temperature: 0.9350289352808355
# [4, 1, 6]
# [5, 2, 7]
# [0, 8, 3]
# Objective function value: 10
#
# Iteration 696 Temperature: 0.9256786459280272
# [4, 1, 2]
# [5, 6, 7]
# [0, 8, 3]
# Objective function value: 10
#
# Iteration 701 Temperature: 0.8803111816824589
# [4, 1, 2]
# [5, 6, 3]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 703 Temperature: 0.862792989166978
# [1, 4, 2]
# [5, 6, 3]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 704 Temperature: 0.8541650592753082
# [1, 6, 2]
# [5, 4, 3]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 705 Temperature: 0.845623408682555
# [1, 6, 2]
# [5, 4, 3]
# [0, 8, 7]
# Objective function value: 8
#
# Iteration 706 Temperature: 0.8371671745957294
# [1, 6, 2]
# [5, 0, 3]
# [4, 8, 7]
# Objective function value: 8
#
# Iteration 710 Temperature: 0.804179447619631
# [1, 6, 2]
# [5, 0, 3]
# [4, 7, 8]
# Objective function value: 8
#
# Iteration 711 Temperature: 0.7961376531434347
# [1, 6, 2]
# [7, 0, 3]
# [4, 5, 8]
# Objective function value: 8
#
# Iteration 714 Temperature: 0.7724915687074215
# [1, 6, 2]
# [7, 0, 3]
# [4, 8, 5]
# Objective function value: 8
#
# Iteration 720 Temperature: 0.7272854775176761
# [1, 6, 2]
# [7, 4, 3]
# [0, 8, 5]
# Objective function value: 8
#
# Iteration 723 Temperature: 0.7056843715499236
# [1, 2, 6]
# [7, 4, 3]
# [0, 8, 5]
# Objective function value: 6
#
# Iteration 726 Temperature: 0.6847248400305193
# [1, 2, 6]
# [7, 4, 3]
# [0, 5, 8]
# Objective function value: 6
#
# Iteration 731 Temperature: 0.651166509788393
# [1, 2, 6]
# [7, 4, 3]
# [0, 5, 8]
# Objective function value: 6
#
# Iteration 732 Temperature: 0.644654844690509
# [1, 2, 6]
# [7, 4, 3]
# [5, 0, 8]
# Objective function value: 7
#
# Iteration 735 Temperature: 0.6255079511483562
# [1, 2, 6]
# [7, 4, 3]
# [5, 0, 8]
# Objective function value: 7
#
# Iteration 739 Temperature: 0.6008604420963859
# [1, 2, 3]
# [7, 4, 6]
# [5, 0, 8]
# Objective function value: 5
#
# Iteration 740 Temperature: 0.594851837675422
# [1, 2, 3]
# [7, 4, 6]
# [5, 0, 8]
# Objective function value: 5
#
# Iteration 741 Temperature: 0.5889033192986678
# [1, 2, 3]
# [7, 4, 6]
# [5, 0, 8]
# Objective function value: 5
#
# Iteration 745 Temperature: 0.5656981787940563
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
# Objective function value: 4
#
# Iteration 746 Temperature: 0.5600411970061157
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
# Objective function value: 4
#
# Iteration 747 Temperature: 0.5544407850360545
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
# Objective function value: 4
#
# Iteration 753 Temperature: 0.5219949931297524
# [1, 2, 3]
# [7, 4, 6]
# [8, 5, 0]
# Objective function value: 4
#
# Iteration 754 Temperature: 0.5167750431984549
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
# Objective function value: 4
#
# Iteration 759 Temperature: 0.4914479241183732
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
# Objective function value: 4
#
# Iteration 760 Temperature: 0.48653344487718947
# [1, 2, 3]
# [7, 4, 6]
# [0, 8, 5]
# Objective function value: 4
#
# Iteration 765 Temperature: 0.4626884650217773
# [1, 2, 3]
# [7, 4, 6]
# [5, 8, 0]
# Objective function value: 4
#
# Iteration 772 Temperature: 0.431255885123074
# [1, 2, 3]
# [7, 4, 6]
# [5, 8, 0]
# Objective function value: 4
#
# Iteration 773 Temperature: 0.4269433262718433
# [1, 2, 3]
# [7, 4, 6]
# [0, 8, 5]
# Objective function value: 4
#
# Iteration 774 Temperature: 0.42267389300912483
# [1, 2, 3]
# [7, 4, 6]
# [0, 8, 5]
# Objective function value: 4
#
# Iteration 775 Temperature: 0.4184471540790336
# [1, 2, 3]
# [7, 4, 6]
# [0, 8, 5]
# Objective function value: 4
#
# Iteration 786 Temperature: 0.3746517444326501
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
# Objective function value: 4
#
# Iteration 788 Temperature: 0.36719617471844035
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
# Objective function value: 3
#
# Iteration 792 Temperature: 0.3527271803217967
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
# Objective function value: 3
#
# Iteration 796 Temperature: 0.3388283220356684
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
# Objective function value: 2
#
# Iteration 804 Temperature: 0.31265203648032774
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
# Objective function value: 2
#
# Iteration 810 Temperature: 0.2943556860160258
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 841 Temperature: 0.21555766074646748
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 851 Temperature: 0.19494648450993418
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 861 Temperature: 0.17630610617676606
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 872 Temperature: 0.15785360131945758
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 878 Temperature: 0.14861603215372882
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 880 Temperature: 0.14565857311386962
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 884 Temperature: 0.13991904415547643
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 892 Temperature: 0.12910955564389176
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Objective function value: 1
#
# Iteration 900 Temperature: 0.11913515747034745
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
# Objective function value: 0
#
# Final Solution:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
# Objective function value: 0
# Heuristic:  Manhatten Tiles
# Time:  0.4141702651977539
# States Explored:  900
# Temperature Chosen: 1000
# Cooling Rate: 0.99
# _____----------------------------__________------_____--_--____-_-__---_-_
# Manhatten Distance Heuristic + Misplaced tiles
# Initial State:
# [4, 3, 0]
# [5, 1, 7]
# [8, 2, 6]
#
# Iteration 1 Temperature: 1000
# [3, 4, 0]
# [5, 1, 7]
# [8, 2, 6]
# Objective function value: 14
#
# Iteration 2 Temperature: 990.0
# [3, 7, 0]
# [5, 1, 4]
# [8, 2, 6]
# Objective function value: 14
#
# Iteration 3 Temperature: 980.1
# [3, 7, 0]
# [5, 1, 4]
# [8, 6, 2]
# Objective function value: 16
#
# Iteration 4 Temperature: 970.299
# [3, 7, 0]
# [4, 1, 5]
# [8, 6, 2]
# Objective function value: 14
#
# Iteration 5 Temperature: 960.59601
# [3, 2, 0]
# [4, 1, 5]
# [8, 6, 7]
# Objective function value: 10
#
# Iteration 6 Temperature: 950.9900498999999
# [5, 2, 0]
# [4, 1, 3]
# [8, 6, 7]
# Objective function value: 10
#
# Iteration 7 Temperature: 941.480149401
# [5, 2, 0]
# [4, 1, 6]
# [8, 3, 7]
# Objective function value: 10
#
# Iteration 8 Temperature: 932.0653479069899
# [5, 2, 4]
# [0, 1, 6]
# [8, 3, 7]
# Objective function value: 13
#
# Iteration 9 Temperature: 922.74469442792
# [5, 2, 4]
# [3, 1, 6]
# [8, 0, 7]
# Objective function value: 13
#
# Iteration 10 Temperature: 913.5172474836407
# [5, 2, 1]
# [3, 4, 6]
# [8, 0, 7]
# Objective function value: 11
#
# Iteration 11 Temperature: 904.3820750088043
# [5, 2, 1]
# [8, 4, 6]
# [3, 0, 7]
# Objective function value: 13
#
# Iteration 12 Temperature: 895.3382542587163
# [0, 2, 1]
# [8, 4, 6]
# [3, 5, 7]
# Objective function value: 12
#
# Iteration 13 Temperature: 886.3848717161292
# [0, 2, 1]
# [8, 5, 6]
# [3, 4, 7]
# Objective function value: 12
#
# Iteration 14 Temperature: 877.5210229989679
# [0, 2, 1]
# [8, 3, 6]
# [5, 4, 7]
# Objective function value: 12
#
# Iteration 15 Temperature: 868.7458127689781
# [0, 2, 1]
# [8, 3, 6]
# [5, 4, 7]
# Objective function value: 12
#
# Iteration 16 Temperature: 860.0583546412884
# [8, 2, 1]
# [0, 3, 6]
# [5, 4, 7]
# Objective function value: 13
#
# Iteration 17 Temperature: 851.4577710948755
# [8, 2, 4]
# [0, 3, 6]
# [5, 1, 7]
# Objective function value: 15
#
# Iteration 18 Temperature: 842.9431933839268
# [8, 2, 4]
# [0, 3, 5]
# [6, 1, 7]
# Objective function value: 17
#
# Iteration 19 Temperature: 834.5137614500875
# [8, 2, 4]
# [0, 3, 1]
# [6, 5, 7]
# Objective function value: 17
#
# Iteration 20 Temperature: 826.1686238355866
# [8, 2, 4]
# [0, 6, 1]
# [3, 5, 7]
# Objective function value: 17
#
# Iteration 21 Temperature: 817.9069375972307
# [8, 2, 4]
# [0, 6, 1]
# [3, 7, 5]
# Objective function value: 17
#
# Iteration 22 Temperature: 809.7278682212584
# [8, 2, 3]
# [0, 6, 1]
# [4, 7, 5]
# Objective function value: 11
#
# Iteration 23 Temperature: 801.6305895390458
# [8, 2, 3]
# [0, 6, 5]
# [4, 7, 1]
# Objective function value: 11
#
# Iteration 24 Temperature: 793.6142836436553
# [8, 5, 3]
# [0, 6, 2]
# [4, 7, 1]
# Objective function value: 13
#
# Iteration 25 Temperature: 785.6781408072187
# [8, 5, 3]
# [1, 6, 2]
# [4, 7, 0]
# Objective function value: 10
#
# Iteration 26 Temperature: 777.8213593991466
# [8, 5, 3]
# [4, 6, 2]
# [1, 7, 0]
# Objective function value: 10
#
# Iteration 27 Temperature: 770.0431458051551
# [8, 5, 3]
# [4, 6, 2]
# [1, 0, 7]
# Objective function value: 11
#
# Iteration 28 Temperature: 762.3427143471035
# [8, 5, 3]
# [2, 6, 4]
# [1, 0, 7]
# Objective function value: 13
#
# Iteration 29 Temperature: 754.7192872036325
# [8, 5, 3]
# [7, 6, 4]
# [1, 0, 2]
# Objective function value: 13
#
# Iteration 30 Temperature: 747.1720943315961
# [8, 5, 3]
# [7, 6, 1]
# [4, 0, 2]
# Objective function value: 13
#
# Iteration 31 Temperature: 739.7003733882801
# [8, 5, 2]
# [7, 6, 1]
# [4, 0, 3]
# Objective function value: 13
#
# Iteration 32 Temperature: 732.3033696543973
# [8, 5, 2]
# [4, 6, 1]
# [7, 0, 3]
# Objective function value: 11
#
# Iteration 33 Temperature: 724.9803359578533
# [8, 5, 2]
# [4, 6, 0]
# [7, 1, 3]
# Objective function value: 11
#
# Iteration 34 Temperature: 717.7305325982747
# [8, 5, 2]
# [4, 6, 0]
# [7, 1, 3]
# Objective function value: 11
#
# Iteration 35 Temperature: 710.553227272292
# [5, 8, 2]
# [4, 6, 0]
# [7, 1, 3]
# Objective function value: 11
#
# Iteration 36 Temperature: 703.4476949995691
# [6, 8, 2]
# [4, 5, 0]
# [7, 1, 3]
# Objective function value: 11
#
# Iteration 37 Temperature: 696.4132180495734
# [6, 2, 8]
# [4, 5, 0]
# [7, 1, 3]
# Objective function value: 11
#
# Iteration 38 Temperature: 689.4490858690776
# [6, 2, 8]
# [4, 5, 0]
# [7, 1, 3]
# Objective function value: 11
#
# Iteration 39 Temperature: 682.5545950103868
# [5, 2, 8]
# [4, 6, 0]
# [7, 1, 3]
# Objective function value: 11
#
# Iteration 40 Temperature: 675.7290490602829
# [5, 2, 8]
# [4, 6, 0]
# [7, 3, 1]
# Objective function value: 13
#
# Iteration 41 Temperature: 668.9717585696801
# [5, 2, 8]
# [3, 6, 0]
# [7, 4, 1]
# Objective function value: 15
#
# Iteration 42 Temperature: 662.2820409839833
# [5, 2, 8]
# [3, 6, 0]
# [4, 7, 1]
# Objective function value: 15
#
# Iteration 43 Temperature: 655.6592205741434
# [5, 2, 3]
# [8, 6, 0]
# [4, 7, 1]
# Objective function value: 11
#
# Iteration 44 Temperature: 649.102628368402
# [5, 6, 3]
# [8, 2, 0]
# [4, 7, 1]
# Objective function value: 13
#
# Iteration 45 Temperature: 642.6116020847179
# [5, 4, 3]
# [8, 2, 0]
# [6, 7, 1]
# Objective function value: 15
#
# Iteration 46 Temperature: 636.1854860638707
# [0, 4, 3]
# [8, 2, 5]
# [6, 7, 1]
# Objective function value: 14
#
# Iteration 47 Temperature: 629.823631203232
# [0, 4, 8]
# [3, 2, 5]
# [6, 7, 1]
# Objective function value: 18
#
# Iteration 48 Temperature: 623.5253948911997
# [0, 7, 8]
# [3, 2, 5]
# [6, 4, 1]
# Objective function value: 20
#
# Iteration 49 Temperature: 617.2901409422876
# [0, 7, 8]
# [3, 2, 5]
# [4, 6, 1]
# Objective function value: 18
#
# Iteration 50 Temperature: 611.1172395328647
# [0, 7, 6]
# [3, 2, 5]
# [4, 8, 1]
# Objective function value: 14
#
# Iteration 51 Temperature: 605.006067137536
# [0, 8, 6]
# [3, 2, 5]
# [4, 7, 1]
# Objective function value: 14
#
# Iteration 52 Temperature: 598.9560064661606
# [0, 8, 6]
# [3, 2, 5]
# [7, 4, 1]
# Objective function value: 14
#
# Iteration 53 Temperature: 592.966446401499
# [0, 8, 5]
# [3, 2, 6]
# [7, 4, 1]
# Objective function value: 14
#
# Iteration 54 Temperature: 587.036781937484
# [0, 8, 5]
# [3, 2, 6]
# [7, 4, 1]
# Objective function value: 14
#
# Iteration 55 Temperature: 581.1664141181092
# [0, 8, 5]
# [6, 2, 3]
# [7, 4, 1]
# Objective function value: 14
#
# Iteration 56 Temperature: 575.3547499769281
# [0, 8, 1]
# [6, 2, 3]
# [7, 4, 5]
# Objective function value: 12
#
# Iteration 57 Temperature: 569.6012024771588
# [1, 8, 0]
# [6, 2, 3]
# [7, 4, 5]
# Objective function value: 10
#
# Iteration 58 Temperature: 563.9051904523873
# [1, 5, 0]
# [6, 2, 3]
# [7, 4, 8]
# Objective function value: 8
#
# Iteration 59 Temperature: 558.2661385478634
# [1, 5, 0]
# [6, 2, 8]
# [7, 4, 3]
# Objective function value: 10
#
# Iteration 60 Temperature: 552.6834771623847
# [5, 1, 0]
# [6, 2, 8]
# [7, 4, 3]
# Objective function value: 12
#
# Iteration 61 Temperature: 547.1566423907609
# [5, 1, 6]
# [0, 2, 8]
# [7, 4, 3]
# Objective function value: 11
#
# Iteration 62 Temperature: 541.6850759668533
# [5, 6, 1]
# [0, 2, 8]
# [7, 4, 3]
# Objective function value: 13
#
# Iteration 63 Temperature: 536.2682252071847
# [5, 6, 0]
# [1, 2, 8]
# [7, 4, 3]
# Objective function value: 12
#
# Iteration 64 Temperature: 530.9055429551129
# [5, 6, 3]
# [1, 2, 8]
# [7, 4, 0]
# Objective function value: 10
#
# Iteration 65 Temperature: 525.5964875255618
# [5, 6, 3]
# [1, 2, 8]
# [7, 4, 0]
# Objective function value: 10
#
# Iteration 66 Temperature: 520.3405226503062
# [5, 6, 4]
# [1, 2, 8]
# [7, 3, 0]
# Objective function value: 14
#
# Iteration 67 Temperature: 515.1371174238031
# [3, 6, 4]
# [1, 2, 8]
# [7, 5, 0]
# Objective function value: 12
#
# Iteration 68 Temperature: 509.9857462495651
# [7, 6, 4]
# [1, 2, 8]
# [3, 5, 0]
# Objective function value: 16
#
# Iteration 69 Temperature: 504.88588878706946
# [7, 6, 4]
# [8, 2, 1]
# [3, 5, 0]
# Objective function value: 18
#
# Iteration 70 Temperature: 499.83702989919874
# [7, 6, 4]
# [8, 2, 1]
# [3, 5, 0]
# Objective function value: 18
#
# Iteration 71 Temperature: 494.83865960020677
# [4, 6, 7]
# [8, 2, 1]
# [3, 5, 0]
# Objective function value: 18
#
# Iteration 72 Temperature: 489.8902730042047
# [4, 6, 3]
# [8, 2, 1]
# [7, 5, 0]
# Objective function value: 10
#
# Iteration 73 Temperature: 484.99137027416265
# [4, 6, 3]
# [8, 1, 2]
# [7, 5, 0]
# Objective function value: 10
#
# Iteration 74 Temperature: 480.14145657142103
# [4, 6, 3]
# [8, 0, 2]
# [7, 5, 1]
# Objective function value: 12
#
# Iteration 75 Temperature: 475.34004200570683
# [4, 5, 3]
# [8, 0, 2]
# [7, 6, 1]
# Objective function value: 12
#
# Iteration 76 Temperature: 470.5866415856498
# [4, 5, 2]
# [8, 0, 3]
# [7, 6, 1]
# Objective function value: 12
#
# Iteration 77 Temperature: 465.88077516979325
# [4, 2, 5]
# [8, 0, 3]
# [7, 6, 1]
# Objective function value: 12
#
# Iteration 78 Temperature: 461.2219674180953
# [4, 2, 5]
# [8, 0, 3]
# [7, 1, 6]
# Objective function value: 10
#
# Iteration 79 Temperature: 456.60974774391434
# [4, 2, 5]
# [8, 0, 7]
# [3, 1, 6]
# Objective function value: 16
#
# Iteration 80 Temperature: 452.0436502664752
# [4, 2, 5]
# [8, 0, 7]
# [3, 1, 6]
# Objective function value: 16
#
# Iteration 81 Temperature: 447.5232137638104
# [7, 2, 5]
# [8, 0, 4]
# [3, 1, 6]
# Objective function value: 16
#
# Iteration 82 Temperature: 443.0479816261723
# [7, 5, 2]
# [8, 0, 4]
# [3, 1, 6]
# Objective function value: 16
#
# Iteration 83 Temperature: 438.6175018099106
# [7, 5, 6]
# [8, 0, 4]
# [3, 1, 2]
# Objective function value: 18
#
# Iteration 84 Temperature: 434.2313267918115
# [7, 6, 5]
# [8, 0, 4]
# [3, 1, 2]
# Objective function value: 20
#
# Iteration 85 Temperature: 429.88901352389337
# [2, 6, 5]
# [8, 0, 4]
# [3, 1, 7]
# Objective function value: 18
#
# Iteration 86 Temperature: 425.59012338865443
# [3, 6, 5]
# [8, 0, 4]
# [2, 1, 7]
# Objective function value: 18
#
# Iteration 87 Temperature: 421.3342221547679
# [1, 6, 5]
# [8, 0, 4]
# [2, 3, 7]
# Objective function value: 16
#
# Iteration 88 Temperature: 417.1208799332202
# [1, 5, 6]
# [8, 0, 4]
# [2, 3, 7]
# Objective function value: 14
#
# Iteration 89 Temperature: 412.949671133888
# [1, 5, 6]
# [7, 0, 4]
# [2, 3, 8]
# Objective function value: 12
#
# Iteration 90 Temperature: 408.8201744225491
# [4, 5, 6]
# [7, 0, 1]
# [2, 3, 8]
# Objective function value: 14
#
# Iteration 91 Temperature: 404.7319726783236
# [4, 5, 6]
# [3, 0, 1]
# [2, 7, 8]
# Objective function value: 14
#
# Iteration 92 Temperature: 400.68465295154033
# [4, 5, 1]
# [3, 0, 6]
# [2, 7, 8]
# Objective function value: 12
#
# Iteration 93 Temperature: 396.6778064220249
# [4, 8, 1]
# [3, 0, 6]
# [2, 7, 5]
# Objective function value: 14
#
# Iteration 94 Temperature: 392.71102835780465
# [5, 8, 1]
# [3, 0, 6]
# [2, 7, 4]
# Objective function value: 16
#
# Iteration 95 Temperature: 388.7839180742266
# [5, 0, 1]
# [3, 8, 6]
# [2, 7, 4]
# Objective function value: 15
#
# Iteration 96 Temperature: 384.89607889348434
# [5, 0, 6]
# [3, 8, 1]
# [2, 7, 4]
# Objective function value: 17
#
# Iteration 97 Temperature: 381.0471181045495
# [5, 0, 3]
# [6, 8, 1]
# [2, 7, 4]
# Objective function value: 15
#
# Iteration 98 Temperature: 377.236646923504
# [5, 8, 3]
# [6, 0, 1]
# [2, 7, 4]
# Objective function value: 16
#
# Iteration 99 Temperature: 373.46428045426893
# [5, 8, 3]
# [6, 0, 1]
# [2, 4, 7]
# Objective function value: 16
#
# Iteration 100 Temperature: 369.7296376497262
# [5, 8, 2]
# [6, 0, 1]
# [3, 4, 7]
# Objective function value: 18
#
# Iteration 101 Temperature: 366.03234127322895
# [5, 8, 4]
# [6, 0, 1]
# [3, 2, 7]
# Objective function value: 20
#
# Iteration 102 Temperature: 362.37201786049667
# [5, 8, 4]
# [6, 0, 1]
# [3, 2, 7]
# Objective function value: 20
#
# Iteration 103 Temperature: 358.7482976818917
# [5, 8, 3]
# [6, 0, 1]
# [4, 2, 7]
# Objective function value: 14
#
# Iteration 104 Temperature: 355.16081470507277
# [5, 8, 3]
# [6, 0, 4]
# [1, 2, 7]
# Objective function value: 14
#
# Iteration 105 Temperature: 351.60920655802204
# [5, 8, 3]
# [6, 0, 4]
# [1, 7, 2]
# Objective function value: 14
#
# Iteration 106 Temperature: 348.0931144924418
# [0, 8, 3]
# [6, 5, 4]
# [1, 7, 2]
# Objective function value: 12
#
# Iteration 107 Temperature: 344.61218334751743
# [4, 8, 3]
# [6, 5, 0]
# [1, 7, 2]
# Objective function value: 11
#
# Iteration 108 Temperature: 341.16606151404227
# [6, 8, 3]
# [4, 5, 0]
# [1, 7, 2]
# Objective function value: 11
#
# Iteration 109 Temperature: 337.75440089890185
# [6, 1, 3]
# [4, 5, 0]
# [8, 7, 2]
# Objective function value: 9
#
# Iteration 110 Temperature: 334.3768568899128
# [6, 1, 3]
# [8, 5, 0]
# [4, 7, 2]
# Objective function value: 11
#
# Iteration 111 Temperature: 331.0330883210137
# [6, 1, 2]
# [8, 5, 0]
# [4, 7, 3]
# Objective function value: 11
#
# Iteration 112 Temperature: 327.7227574378035
# [6, 1, 2]
# [8, 5, 0]
# [3, 7, 4]
# Objective function value: 15
#
# Iteration 113 Temperature: 324.44552986342546
# [6, 1, 2]
# [3, 5, 0]
# [8, 7, 4]
# Objective function value: 13
#
# Iteration 114 Temperature: 321.2010745647912
# [8, 1, 2]
# [3, 5, 0]
# [6, 7, 4]
# Objective function value: 15
#
# Iteration 115 Temperature: 317.9890638191433
# [8, 1, 2]
# [3, 5, 0]
# [6, 4, 7]
# Objective function value: 15
#
# Iteration 116 Temperature: 314.8091731809519
# [8, 0, 2]
# [3, 5, 1]
# [6, 4, 7]
# Objective function value: 17
#
# Iteration 117 Temperature: 311.6610814491424
# [8, 4, 2]
# [3, 5, 1]
# [6, 0, 7]
# Objective function value: 17
#
# Iteration 118 Temperature: 308.54447063465096
# [8, 1, 2]
# [3, 5, 4]
# [6, 0, 7]
# Objective function value: 15
#
# Iteration 119 Temperature: 305.45902592830447
# [8, 1, 2]
# [3, 0, 4]
# [6, 5, 7]
# Objective function value: 16
#
# Iteration 120 Temperature: 302.40443566902144
# [8, 7, 2]
# [3, 0, 4]
# [6, 5, 1]
# Objective function value: 20
#
# Iteration 121 Temperature: 299.3803913123312
# [8, 7, 2]
# [1, 0, 4]
# [6, 5, 3]
# Objective function value: 16
#
# Iteration 122 Temperature: 296.3865873992079
# [8, 6, 2]
# [1, 0, 4]
# [7, 5, 3]
# Objective function value: 12
#
# Iteration 123 Temperature: 293.4227215252158
# [8, 5, 2]
# [1, 0, 4]
# [7, 6, 3]
# Objective function value: 12
#
# Iteration 124 Temperature: 290.48849430996364
# [8, 5, 2]
# [1, 0, 3]
# [7, 6, 4]
# Objective function value: 12
#
# Iteration 125 Temperature: 287.583609366864
# [8, 5, 2]
# [1, 0, 3]
# [7, 6, 4]
# Objective function value: 12
#
# Iteration 126 Temperature: 284.70777327319536
# [3, 5, 2]
# [1, 0, 8]
# [7, 6, 4]
# Objective function value: 12
#
# Iteration 127 Temperature: 281.8606955404634
# [3, 5, 2]
# [0, 1, 8]
# [7, 6, 4]
# Objective function value: 13
#
# Iteration 128 Temperature: 279.04208858505876
# [0, 5, 2]
# [3, 1, 8]
# [7, 6, 4]
# Objective function value: 14
#
# Iteration 129 Temperature: 276.25166769920816
# [0, 5, 4]
# [3, 1, 8]
# [7, 6, 2]
# Objective function value: 16
#
# Iteration 130 Temperature: 273.48915102221605
# [7, 5, 4]
# [3, 1, 8]
# [0, 6, 2]
# Objective function value: 18
#
# Iteration 131 Temperature: 270.7542595119939
# [2, 5, 4]
# [3, 1, 8]
# [0, 6, 7]
# Objective function value: 16
#
# Iteration 132 Temperature: 268.04671691687395
# [2, 5, 6]
# [3, 1, 8]
# [0, 4, 7]
# Objective function value: 14
#
# Iteration 133 Temperature: 265.3662497477052
# [2, 5, 0]
# [3, 1, 8]
# [6, 4, 7]
# Objective function value: 16
#
# Iteration 134 Temperature: 262.7125872502281
# [2, 3, 0]
# [5, 1, 8]
# [6, 4, 7]
# Objective function value: 14
#
# Iteration 135 Temperature: 260.08546137772584
# [6, 3, 0]
# [5, 1, 8]
# [2, 4, 7]
# Objective function value: 16
#
# Iteration 136 Temperature: 257.4846067639486
# [6, 4, 0]
# [5, 1, 8]
# [2, 3, 7]
# Objective function value: 18
#
# Iteration 137 Temperature: 254.9097606963091
# [6, 7, 0]
# [5, 1, 8]
# [2, 3, 4]
# Objective function value: 20
#
# Iteration 138 Temperature: 252.360663089346
# [6, 7, 5]
# [0, 1, 8]
# [2, 3, 4]
# Objective function value: 21
#
# Iteration 139 Temperature: 249.83705645845254
# [6, 7, 5]
# [0, 1, 8]
# [2, 3, 4]
# Objective function value: 21
#
# Iteration 140 Temperature: 247.33868589386802
# [6, 7, 5]
# [0, 3, 8]
# [2, 1, 4]
# Objective function value: 21
#
# Iteration 141 Temperature: 244.86529903492934
# [5, 7, 6]
# [0, 3, 8]
# [2, 1, 4]
# Objective function value: 19
#
# Iteration 142 Temperature: 242.41664604458003
# [5, 7, 6]
# [0, 3, 4]
# [2, 1, 8]
# Objective function value: 17
#
# Iteration 143 Temperature: 239.99247958413423
# [5, 7, 6]
# [2, 3, 4]
# [0, 1, 8]
# Objective function value: 16
#
# Iteration 144 Temperature: 237.5925547882929
# [1, 7, 6]
# [2, 3, 4]
# [0, 5, 8]
# Objective function value: 12
#
# Iteration 145 Temperature: 235.21662924040996
# [8, 7, 6]
# [2, 3, 4]
# [0, 5, 1]
# Objective function value: 18
#
# Iteration 146 Temperature: 232.86446294800587
# [8, 7, 6]
# [2, 5, 4]
# [0, 3, 1]
# Objective function value: 18
#
# Iteration 147 Temperature: 230.5358183185258
# [8, 7, 6]
# [0, 5, 4]
# [2, 3, 1]
# Objective function value: 19
#
# Iteration 148 Temperature: 228.23046013534054
# [8, 7, 0]
# [6, 5, 4]
# [2, 3, 1]
# Objective function value: 20
#
# Iteration 149 Temperature: 225.94815553398712
# [8, 7, 0]
# [6, 5, 3]
# [2, 4, 1]
# Objective function value: 18
#
# Iteration 150 Temperature: 223.68867397864724
# [4, 7, 0]
# [6, 5, 3]
# [2, 8, 1]
# Objective function value: 14
#
# Iteration 151 Temperature: 221.45178723886076
# [4, 7, 0]
# [8, 5, 3]
# [2, 6, 1]
# Objective function value: 16
#
# Iteration 152 Temperature: 219.23726936647216
# [4, 7, 0]
# [8, 5, 2]
# [3, 6, 1]
# Objective function value: 18
#
# Iteration 153 Temperature: 217.04489667280743
# [4, 7, 0]
# [8, 5, 2]
# [3, 6, 1]
# Objective function value: 18
#
# Iteration 154 Temperature: 214.87444770607934
# [4, 7, 0]
# [8, 5, 2]
# [3, 6, 1]
# Objective function value: 18
#
# Iteration 155 Temperature: 212.72570322901854
# [4, 7, 0]
# [8, 3, 2]
# [5, 6, 1]
# Objective function value: 18
#
# Iteration 156 Temperature: 210.59844619672836
# [2, 7, 0]
# [8, 3, 4]
# [5, 6, 1]
# Objective function value: 18
#
# Iteration 157 Temperature: 208.49246173476106
# [2, 7, 0]
# [6, 3, 4]
# [5, 8, 1]
# Objective function value: 16
#
# Iteration 158 Temperature: 206.40753711741345
# [2, 7, 0]
# [1, 3, 4]
# [5, 8, 6]
# Objective function value: 12
#
# Iteration 159 Temperature: 204.3434617462393
# [5, 7, 0]
# [1, 3, 4]
# [2, 8, 6]
# Objective function value: 14
#
# Iteration 160 Temperature: 202.30002712877692
# [5, 7, 0]
# [1, 3, 4]
# [2, 8, 6]
# Objective function value: 14
#
# Iteration 161 Temperature: 200.27702685748915
# [7, 5, 0]
# [1, 3, 4]
# [2, 8, 6]
# Objective function value: 12
#
# Iteration 162 Temperature: 198.27425658891426
# [7, 5, 1]
# [0, 3, 4]
# [2, 8, 6]
# Objective function value: 13
#
# Iteration 163 Temperature: 196.29151402302512
# [7, 5, 1]
# [0, 3, 2]
# [4, 8, 6]
# Objective function value: 11
#
# Iteration 164 Temperature: 194.32859888279486
# [7, 1, 5]
# [0, 3, 2]
# [4, 8, 6]
# Objective function value: 11
#
# Iteration 165 Temperature: 192.38531289396693
# [7, 3, 5]
# [0, 1, 2]
# [4, 8, 6]
# Objective function value: 11
#
# Iteration 166 Temperature: 190.46145976502726
# [7, 3, 5]
# [0, 1, 2]
# [4, 8, 6]
# Objective function value: 11
#
# Iteration 167 Temperature: 188.556845167377
# [7, 3, 5]
# [0, 6, 2]
# [4, 8, 1]
# Objective function value: 13
#
# Iteration 168 Temperature: 186.67127671570321
# [1, 3, 5]
# [0, 6, 2]
# [4, 8, 7]
# Objective function value: 9
#
# Iteration 169 Temperature: 184.8045639485462
# [1, 3, 8]
# [0, 6, 2]
# [4, 5, 7]
# Objective function value: 11
#
# Iteration 170 Temperature: 182.95651830906073
# [1, 3, 8]
# [0, 6, 2]
# [4, 5, 7]
# Objective function value: 11
#
# Iteration 171 Temperature: 181.12695312597012
# [1, 3, 8]
# [0, 2, 6]
# [4, 5, 7]
# Objective function value: 9
#
# Iteration 172 Temperature: 179.3156835947104
# [1, 3, 4]
# [0, 2, 6]
# [8, 5, 7]
# Objective function value: 9
#
# Iteration 173 Temperature: 177.5225267587633
# [1, 3, 5]
# [0, 2, 6]
# [8, 4, 7]
# Objective function value: 9
#
# Iteration 174 Temperature: 175.74730149117565
# [1, 6, 5]
# [0, 2, 3]
# [8, 4, 7]
# Objective function value: 11
#
# Iteration 175 Temperature: 173.98982847626388
# [1, 6, 5]
# [0, 2, 4]
# [8, 3, 7]
# Objective function value: 13
#
# Iteration 176 Temperature: 172.24993019150125
# [1, 4, 5]
# [0, 2, 6]
# [8, 3, 7]
# Objective function value: 11
#
# Iteration 178 Temperature: 168.82215658069038
# [0, 4, 5]
# [1, 2, 6]
# [8, 3, 7]
# Objective function value: 12
#
# Iteration 179 Temperature: 167.13393501488346
# [3, 4, 5]
# [1, 2, 6]
# [8, 0, 7]
# Objective function value: 11
#
# Iteration 180 Temperature: 165.46259566473464
# [3, 2, 5]
# [1, 4, 6]
# [8, 0, 7]
# Objective function value: 9
#
# Iteration 181 Temperature: 163.80796970808728
# [6, 2, 5]
# [1, 4, 3]
# [8, 0, 7]
# Objective function value: 11
#
# Iteration 182 Temperature: 162.1698900110064
# [6, 5, 2]
# [1, 4, 3]
# [8, 0, 7]
# Objective function value: 11
#
# Iteration 183 Temperature: 160.54819111089634
# [6, 3, 2]
# [1, 4, 5]
# [8, 0, 7]
# Objective function value: 11
#
# Iteration 184 Temperature: 158.94270919978737
# [1, 3, 2]
# [6, 4, 5]
# [8, 0, 7]
# Objective function value: 9
#
# Iteration 185 Temperature: 157.3532821077895
# [2, 3, 1]
# [6, 4, 5]
# [8, 0, 7]
# Objective function value: 11
#
# Iteration 186 Temperature: 155.77974928671162
# [0, 3, 1]
# [6, 4, 5]
# [8, 2, 7]
# Objective function value: 12
#
# Iteration 187 Temperature: 154.2219517938445
# [0, 3, 5]
# [6, 4, 1]
# [8, 2, 7]
# Objective function value: 14
#
# Iteration 188 Temperature: 152.67973227590608
# [0, 3, 5]
# [4, 6, 1]
# [8, 2, 7]
# Objective function value: 12
#
# Iteration 189 Temperature: 151.15293495314702
# [6, 3, 5]
# [4, 0, 1]
# [8, 2, 7]
# Objective function value: 14
#
# Iteration 190 Temperature: 149.64140560361557
# [6, 3, 5]
# [4, 2, 1]
# [8, 0, 7]
# Objective function value: 13
#
# Iteration 191 Temperature: 148.14499154757942
# [6, 3, 5]
# [4, 8, 1]
# [2, 0, 7]
# Objective function value: 15
#
# Iteration 192 Temperature: 146.66354163210363
# [6, 8, 5]
# [4, 3, 1]
# [2, 0, 7]
# Objective function value: 17
#
# Iteration 193 Temperature: 145.1969062157826
# [8, 6, 5]
# [4, 3, 1]
# [2, 0, 7]
# Objective function value: 17
#
# Iteration 194 Temperature: 143.7449371536248
# [8, 6, 5]
# [4, 7, 1]
# [2, 0, 3]
# Objective function value: 17
#
# Iteration 195 Temperature: 142.30748778208854
# [8, 6, 5]
# [3, 7, 1]
# [2, 0, 4]
# Objective function value: 21
#
# Iteration 196 Temperature: 140.88441290426766
# [8, 6, 3]
# [5, 7, 1]
# [2, 0, 4]
# Objective function value: 17
#
# Iteration 197 Temperature: 139.47556877522499
# [4, 6, 3]
# [5, 7, 1]
# [2, 0, 8]
# Objective function value: 13
#
# Iteration 198 Temperature: 138.08081308747273
# [6, 4, 3]
# [5, 7, 1]
# [2, 0, 8]
# Objective function value: 15
#
# Iteration 199 Temperature: 136.700004956598
# [6, 3, 4]
# [5, 7, 1]
# [2, 0, 8]
# Objective function value: 17
#
# Iteration 200 Temperature: 135.33300490703203
# [6, 3, 4]
# [5, 7, 1]
# [2, 0, 8]
# Objective function value: 17
#
# Iteration 201 Temperature: 133.97967485796173
# [6, 3, 4]
# [5, 0, 1]
# [2, 7, 8]
# Objective function value: 16
#
# Iteration 202 Temperature: 132.6398781093821
# [6, 7, 4]
# [5, 0, 1]
# [2, 3, 8]
# Objective function value: 20
#
# Iteration 203 Temperature: 131.31347932828828
# [6, 7, 4]
# [5, 0, 8]
# [2, 3, 1]
# Objective function value: 22
#
# Iteration 204 Temperature: 130.0003445350054
# [6, 7, 4]
# [5, 1, 8]
# [2, 3, 0]
# Objective function value: 20
#
# Iteration 205 Temperature: 128.70034108965535
# [3, 7, 4]
# [5, 1, 8]
# [2, 6, 0]
# Objective function value: 18
#
# Iteration 206 Temperature: 127.4133376787588
# [3, 7, 4]
# [5, 1, 8]
# [2, 6, 0]
# Objective function value: 18
#
# Iteration 207 Temperature: 126.1392043019712
# [1, 7, 4]
# [5, 3, 8]
# [2, 6, 0]
# Objective function value: 16
#
# Iteration 208 Temperature: 124.8778122589515
# [1, 7, 4]
# [6, 3, 8]
# [2, 5, 0]
# Objective function value: 16
#
# Iteration 209 Temperature: 123.62903413636198
# [1, 5, 4]
# [6, 3, 8]
# [2, 7, 0]
# Objective function value: 14
#
# Iteration 210 Temperature: 122.39274379499835
# [1, 5, 4]
# [6, 3, 8]
# [2, 0, 7]
# Objective function value: 15
#
# Iteration 211 Temperature: 121.16881635704837
# [1, 5, 7]
# [6, 3, 8]
# [2, 0, 4]
# Objective function value: 17
#
# Iteration 212 Temperature: 119.95712819347789
# [1, 5, 7]
# [6, 3, 8]
# [2, 0, 4]
# Objective function value: 17
#
# Iteration 213 Temperature: 118.7575569115431
# [5, 1, 7]
# [6, 3, 8]
# [2, 0, 4]
# Objective function value: 19
#
# Iteration 214 Temperature: 117.56998134242767
# [4, 1, 7]
# [6, 3, 8]
# [2, 0, 5]
# Objective function value: 17
#
# Iteration 215 Temperature: 116.3942815290034
# [3, 1, 7]
# [6, 4, 8]
# [2, 0, 5]
# Objective function value: 17
#
# Iteration 216 Temperature: 115.23033871371337
# [3, 1, 7]
# [6, 8, 4]
# [2, 0, 5]
# Objective function value: 17
#
# Iteration 217 Temperature: 114.07803532657623
# [3, 1, 7]
# [6, 8, 5]
# [2, 0, 4]
# Objective function value: 17
#
# Iteration 218 Temperature: 112.93725497331046
# [0, 1, 7]
# [6, 8, 5]
# [2, 3, 4]
# Objective function value: 18
#
# Iteration 219 Temperature: 111.80788242357735
# [0, 1, 8]
# [6, 7, 5]
# [2, 3, 4]
# Objective function value: 18
#
# Iteration 220 Temperature: 110.68980359934157
# [0, 1, 8]
# [6, 5, 7]
# [2, 3, 4]
# Objective function value: 18
#
# Iteration 221 Temperature: 109.58290556334816
# [0, 7, 8]
# [6, 5, 1]
# [2, 3, 4]
# Objective function value: 20
#
# Iteration 222 Temperature: 108.48707650771468
# [0, 7, 8]
# [3, 5, 1]
# [2, 6, 4]
# Objective function value: 20
#
# Iteration 223 Temperature: 107.40220574263753
# [0, 7, 8]
# [3, 5, 6]
# [2, 1, 4]
# Objective function value: 18
#
# Iteration 224 Temperature: 106.32818368521116
# [0, 7, 8]
# [3, 5, 2]
# [6, 1, 4]
# Objective function value: 20
#
# Iteration 225 Temperature: 105.26490184835905
# [0, 1, 8]
# [3, 5, 2]
# [6, 7, 4]
# Objective function value: 16
#
# Iteration 226 Temperature: 104.21225282987545
# [0, 1, 2]
# [3, 5, 8]
# [6, 7, 4]
# Objective function value: 14
#
# Iteration 227 Temperature: 103.17013030157669
# [0, 8, 2]
# [3, 5, 1]
# [6, 7, 4]
# Objective function value: 16
#
# Iteration 228 Temperature: 102.13842899856093
# [0, 8, 2]
# [4, 5, 1]
# [6, 7, 3]
# Objective function value: 12
#
# Iteration 229 Temperature: 101.11704470857532
# [0, 6, 2]
# [4, 5, 1]
# [8, 7, 3]
# Objective function value: 10
#
# Iteration 230 Temperature: 100.10587426148956
# [0, 6, 2]
# [4, 1, 5]
# [8, 7, 3]
# Objective function value: 10
#
# Iteration 231 Temperature: 99.10481551887466
# [0, 6, 2]
# [8, 1, 5]
# [4, 7, 3]
# Objective function value: 12
#
# Iteration 232 Temperature: 98.11376736368591
# [0, 6, 2]
# [7, 1, 5]
# [4, 8, 3]
# Objective function value: 10
#
# Iteration 233 Temperature: 97.13262969004904
# [0, 7, 2]
# [6, 1, 5]
# [4, 8, 3]
# Objective function value: 12
#
# Iteration 234 Temperature: 96.16130339314856
# [0, 7, 2]
# [6, 1, 5]
# [4, 3, 8]
# Objective function value: 14
#
# Iteration 235 Temperature: 95.19969035921707
# [0, 8, 2]
# [6, 1, 5]
# [4, 3, 7]
# Objective function value: 14
#
# Iteration 236 Temperature: 94.2476934556249
# [0, 8, 1]
# [6, 2, 5]
# [4, 3, 7]
# Objective function value: 14
#
# Iteration 237 Temperature: 93.30521652106864
# [0, 8, 1]
# [3, 2, 5]
# [4, 6, 7]
# Objective function value: 14
#
# Iteration 238 Temperature: 92.37216435585796
# [0, 8, 4]
# [3, 2, 5]
# [1, 6, 7]
# Objective function value: 16
#
# Iteration 239 Temperature: 91.44844271229938
# [0, 4, 8]
# [3, 2, 5]
# [1, 6, 7]
# Objective function value: 16
#
# Iteration 240 Temperature: 90.53395828517638
# [3, 4, 8]
# [0, 2, 5]
# [1, 6, 7]
# Objective function value: 15
#
# Iteration 241 Temperature: 89.62861870232462
# [3, 4, 8]
# [0, 6, 5]
# [1, 2, 7]
# Objective function value: 15
#
# Iteration 242 Temperature: 88.73233251530137
# [8, 4, 3]
# [0, 6, 5]
# [1, 2, 7]
# Objective function value: 13
#
# Iteration 243 Temperature: 87.84500919014835
# [8, 4, 3]
# [6, 0, 5]
# [1, 2, 7]
# Objective function value: 14
#
# Iteration 244 Temperature: 86.96655909824686
# [8, 4, 3]
# [6, 0, 5]
# [1, 7, 2]
# Objective function value: 14
#
# Iteration 245 Temperature: 86.0968935072644
# [8, 4, 3]
# [6, 7, 5]
# [1, 0, 2]
# Objective function value: 15
#
# Iteration 246 Temperature: 85.23592457219175
# [8, 4, 3]
# [6, 7, 5]
# [0, 1, 2]
# Objective function value: 16
#
# Iteration 247 Temperature: 84.38356532646984
# [8, 4, 3]
# [6, 7, 5]
# [0, 1, 2]
# Objective function value: 16
#
# Iteration 248 Temperature: 83.53972967320513
# [8, 4, 3]
# [6, 7, 5]
# [0, 1, 2]
# Objective function value: 16
#
# Iteration 249 Temperature: 82.70433237647308
# [8, 4, 3]
# [6, 0, 5]
# [7, 1, 2]
# Objective function value: 14
#
# Iteration 250 Temperature: 81.87728905270835
# [8, 4, 6]
# [3, 0, 5]
# [7, 1, 2]
# Objective function value: 16
#
# Iteration 251 Temperature: 81.05851616218126
# [8, 4, 6]
# [1, 0, 5]
# [7, 3, 2]
# Objective function value: 14
#
# Iteration 252 Temperature: 80.24793100055945
# [8, 4, 6]
# [1, 0, 2]
# [7, 3, 5]
# Objective function value: 14
#
# Iteration 253 Temperature: 79.44545169055385
# [8, 4, 2]
# [1, 0, 6]
# [7, 3, 5]
# Objective function value: 12
#
# Iteration 254 Temperature: 78.6509971736483
# [8, 4, 2]
# [1, 7, 6]
# [0, 3, 5]
# Objective function value: 14
#
# Iteration 255 Temperature: 77.86448720191183
# [8, 4, 2]
# [1, 0, 6]
# [7, 3, 5]
# Objective function value: 12
#
# Iteration 256 Temperature: 77.08584232989271
# [6, 4, 2]
# [1, 0, 8]
# [7, 3, 5]
# Objective function value: 14
#
# Iteration 257 Temperature: 76.31498390659378
# [6, 4, 2]
# [8, 0, 1]
# [7, 3, 5]
# Objective function value: 16
#
# Iteration 258 Temperature: 75.55183406752785
# [6, 4, 2]
# [8, 0, 1]
# [7, 3, 5]
# Objective function value: 16
#
# Iteration 259 Temperature: 74.79631572685257
# [4, 6, 2]
# [8, 0, 1]
# [7, 3, 5]
# Objective function value: 14
#
# Iteration 260 Temperature: 74.04835256958404
# [4, 6, 2]
# [5, 0, 1]
# [7, 3, 8]
# Objective function value: 12
#
# Iteration 261 Temperature: 73.3078690438882
# [4, 6, 2]
# [5, 0, 8]
# [7, 3, 1]
# Objective function value: 14
#
# Iteration 262 Temperature: 72.57479035344932
# [4, 1, 2]
# [5, 0, 8]
# [7, 3, 6]
# Objective function value: 10
#
# Iteration 263 Temperature: 71.84904244991482
# [4, 1, 2]
# [5, 0, 8]
# [7, 3, 6]
# Objective function value: 10
#
# Iteration 264 Temperature: 71.13055202541567
# [7, 1, 2]
# [5, 0, 8]
# [4, 3, 6]
# Objective function value: 12
#
# Iteration 265 Temperature: 70.41924650516151
# [2, 1, 7]
# [5, 0, 8]
# [4, 3, 6]
# Objective function value: 14
#
# Iteration 266 Temperature: 69.71505404010989
# [2, 7, 1]
# [5, 0, 8]
# [4, 3, 6]
# Objective function value: 14
#
# Iteration 267 Temperature: 69.0179034997088
# [2, 7, 0]
# [5, 1, 8]
# [4, 3, 6]
# Objective function value: 14
#
# Iteration 268 Temperature: 68.32772446471171
# [3, 7, 0]
# [5, 1, 8]
# [4, 2, 6]
# Objective function value: 14
#
# Iteration 269 Temperature: 67.64444722006459
# [7, 3, 0]
# [5, 1, 8]
# [4, 2, 6]
# Objective function value: 12
#
# Iteration 270 Temperature: 66.96800274786395
# [7, 3, 0]
# [5, 1, 4]
# [8, 2, 6]
# Objective function value: 12
#
# Iteration 271 Temperature: 66.29832272038531
# [7, 3, 0]
# [5, 6, 4]
# [8, 2, 1]
# Objective function value: 14
#
# Iteration 272 Temperature: 65.63533949318146
# [7, 3, 0]
# [5, 6, 4]
# [8, 2, 1]
# Objective function value: 14
#
# Iteration 273 Temperature: 64.97898609824965
# [7, 3, 0]
# [5, 6, 8]
# [4, 2, 1]
# Objective function value: 14
#
# Iteration 274 Temperature: 64.32919623726715
# [7, 3, 0]
# [5, 6, 8]
# [4, 2, 1]
# Objective function value: 14
#
# Iteration 275 Temperature: 63.68590427489448
# [7, 3, 0]
# [5, 6, 1]
# [4, 2, 8]
# Objective function value: 12
#
# Iteration 276 Temperature: 63.04904523214554
# [7, 3, 0]
# [1, 6, 5]
# [4, 2, 8]
# Objective function value: 10
#
# Iteration 277 Temperature: 62.418554779824085
# [7, 3, 0]
# [1, 6, 8]
# [4, 2, 5]
# Objective function value: 12
#
# Iteration 278 Temperature: 61.79436923202584
# [3, 7, 0]
# [1, 6, 8]
# [4, 2, 5]
# Objective function value: 14
#
# Iteration 279 Temperature: 61.17642553970558
# [3, 2, 0]
# [1, 6, 8]
# [4, 7, 5]
# Objective function value: 10
#
# Iteration 281 Temperature: 59.95901467146544
# [3, 5, 0]
# [1, 6, 8]
# [4, 7, 2]
# Objective function value: 12
#
# ...
#
# Iteration 512 Temperature: 5.882804816831986
# [3, 1, 8]
# [7, 6, 0]
# [2, 4, 5]
# Objective function value: 15
#
# Iteration 513 Temperature: 5.823976768663666
# [6, 1, 8]
# [7, 3, 0]
# [2, 4, 5]
# Objective function value: 17
#
# Iteration 514 Temperature: 5.76573700097703
# [6, 1, 7]
# [8, 3, 0]
# [2, 4, 5]
# Objective function value: 19
#
# Iteration 515 Temperature: 5.7080796309672595
# [1, 6, 7]
# [8, 3, 0]
# [2, 4, 5]
# Objective function value: 17
#
# Iteration 516 Temperature: 5.650998834657587
# [1, 6, 7]
# [3, 8, 0]
# [2, 4, 5]
# Objective function value: 17
#
# Iteration 517 Temperature: 5.594488846311011
# [0, 6, 7]
# [3, 8, 1]
# [2, 4, 5]
# Objective function value: 20
#
# Iteration 518 Temperature: 5.5385439578479
# [4, 6, 7]
# [3, 8, 1]
# [2, 0, 5]
# Objective function value: 19
#
# Iteration 519 Temperature: 5.483158518269422
# [4, 6, 3]
# [7, 8, 1]
# [2, 0, 5]
# Objective function value: 13
#
# Iteration 520 Temperature: 5.428326933086727
# [4, 6, 0]
# [7, 8, 1]
# [2, 3, 5]
# Objective function value: 16
#
# Iteration 522 Temperature: 5.320303227118301
# [4, 0, 6]
# [7, 8, 1]
# [2, 3, 5]
# Objective function value: 15
#
# Iteration 523 Temperature: 5.267100194847118
# [4, 0, 6]
# [7, 3, 1]
# [2, 8, 5]
# Objective function value: 13
#
# Iteration 526 Temperature: 5.110662051959964
# [4, 0, 6]
# [7, 3, 1]
# [2, 8, 5]
# Objective function value: 13
#
# Iteration 527 Temperature: 5.059555431440364
# [4, 0, 6]
# [7, 3, 1]
# [2, 8, 5]
# Objective function value: 13
#
# Iteration 528 Temperature: 5.00895987712596
# [4, 0, 3]
# [7, 6, 1]
# [2, 8, 5]
# Objective function value: 11
#
# Iteration 529 Temperature: 4.9588702783547
# [4, 0, 3]
# [7, 6, 1]
# [2, 8, 5]
# Objective function value: 11
#
# Iteration 530 Temperature: 4.909281575571153
# [4, 6, 3]
# [7, 0, 1]
# [2, 8, 5]
# Objective function value: 12
#
# Iteration 531 Temperature: 4.860188759815442
# [4, 6, 3]
# [0, 7, 1]
# [2, 8, 5]
# Objective function value: 13
#
# Iteration 532 Temperature: 4.811586872217287
# [4, 6, 1]
# [0, 7, 3]
# [2, 8, 5]
# Objective function value: 13
#
# Iteration 534 Temperature: 4.715836293460163
# [4, 6, 1]
# [0, 3, 7]
# [2, 8, 5]
# Objective function value: 15
#
# Iteration 535 Temperature: 4.668677930525561
# [4, 5, 1]
# [0, 3, 7]
# [2, 8, 6]
# Objective function value: 13
#
# Iteration 537 Temperature: 4.575771239708103
# [4, 5, 1]
# [0, 3, 7]
# [2, 8, 6]
# Objective function value: 13
#
# Iteration 538 Temperature: 4.530013527311022
# [5, 4, 1]
# [0, 3, 7]
# [2, 8, 6]
# Objective function value: 15
#
# Iteration 539 Temperature: 4.484713392037912
# [1, 4, 5]
# [0, 3, 7]
# [2, 8, 6]
# Objective function value: 13
#
# Iteration 540 Temperature: 4.439866258117532
# [1, 5, 4]
# [0, 3, 7]
# [2, 8, 6]
# Objective function value: 13
#
# Iteration 541 Temperature: 4.395467595536357
# [2, 5, 4]
# [0, 3, 7]
# [1, 8, 6]
# Objective function value: 13
#
# Iteration 542 Temperature: 4.351512919580993
# [2, 4, 5]
# [0, 3, 7]
# [1, 8, 6]
# Objective function value: 13
#
# Iteration 543 Temperature: 4.307997790385183
# [2, 1, 5]
# [0, 3, 7]
# [4, 8, 6]
# Objective function value: 11
#
# Iteration 544 Temperature: 4.264917812481332
# [1, 2, 5]
# [0, 3, 7]
# [4, 8, 6]
# Objective function value: 9
#
# Iteration 545 Temperature: 4.222268634356518
# [3, 2, 5]
# [0, 1, 7]
# [4, 8, 6]
# Objective function value: 11
#
# Iteration 546 Temperature: 4.180045948012953
# [3, 2, 5]
# [0, 8, 7]
# [4, 1, 6]
# Objective function value: 13
#
# Iteration 549 Temperature: 4.0558944033110205
# [3, 2, 5]
# [0, 8, 4]
# [7, 1, 6]
# Objective function value: 11
#
# Iteration 550 Temperature: 4.01533545927791
# [3, 2, 5]
# [0, 1, 4]
# [7, 8, 6]
# Objective function value: 9
#
# Iteration 551 Temperature: 3.975182104685131
# [5, 2, 3]
# [0, 1, 4]
# [7, 8, 6]
# Objective function value: 7
#
# Iteration 552 Temperature: 3.9354302836382797
# [5, 2, 3]
# [0, 1, 4]
# [7, 8, 6]
# Objective function value: 7
#
# Iteration 554 Temperature: 3.8571152209938777
# [5, 2, 3]
# [0, 1, 4]
# [7, 8, 6]
# Objective function value: 7
#
# Iteration 555 Temperature: 3.8185440687839387
# [5, 2, 3]
# [0, 7, 4]
# [1, 8, 6]
# Objective function value: 9
#
# Iteration 556 Temperature: 3.7803586280960992
# [5, 6, 3]
# [0, 7, 4]
# [1, 8, 2]
# Objective function value: 13
#
# Iteration 557 Temperature: 3.7425550418151383
# [3, 6, 5]
# [0, 7, 4]
# [1, 8, 2]
# Objective function value: 15
#
# Iteration 558 Temperature: 3.705129491396987
# [3, 6, 5]
# [8, 7, 4]
# [1, 0, 2]
# Objective function value: 17
#
# Iteration 559 Temperature: 3.668078196483017
# [0, 6, 5]
# [8, 7, 4]
# [1, 3, 2]
# Objective function value: 18
#
# Iteration 560 Temperature: 3.6313974145181867
# [0, 6, 5]
# [3, 7, 4]
# [1, 8, 2]
# Objective function value: 16
#
# Iteration 561 Temperature: 3.5950834403730045
# [0, 6, 5]
# [3, 7, 4]
# [1, 8, 2]
# Objective function value: 16
#
# Iteration 562 Temperature: 3.5591326059692743
# [0, 6, 8]
# [3, 7, 4]
# [1, 5, 2]
# Objective function value: 18
#
# Iteration 563 Temperature: 3.5235412799095815
# [8, 6, 0]
# [3, 7, 4]
# [1, 5, 2]
# Objective function value: 18
#
# Iteration 564 Temperature: 3.4883058671104856
# [7, 6, 0]
# [3, 8, 4]
# [1, 5, 2]
# Objective function value: 16
#
# Iteration 565 Temperature: 3.4534228084393805
# [7, 6, 0]
# [3, 8, 4]
# [1, 2, 5]
# Objective function value: 16
#
# Iteration 566 Temperature: 3.4188885803549867
# [7, 6, 0]
# [3, 8, 1]
# [4, 2, 5]
# Objective function value: 16
#
# Iteration 567 Temperature: 3.3846996945514367
# [5, 6, 0]
# [3, 8, 1]
# [4, 2, 7]
# Objective function value: 16
#
# Iteration 568 Temperature: 3.3508526976059225
# [5, 6, 0]
# [3, 2, 1]
# [4, 8, 7]
# Objective function value: 14
#
# Iteration 569 Temperature: 3.3173441706298634
# [5, 6, 3]
# [0, 2, 1]
# [4, 8, 7]
# Objective function value: 11
#
# Iteration 570 Temperature: 3.2841707289235647
# [6, 5, 3]
# [0, 2, 1]
# [4, 8, 7]
# Objective function value: 11
#
# Iteration 571 Temperature: 3.251329021634329
# [6, 5, 3]
# [0, 2, 8]
# [4, 1, 7]
# Objective function value: 13
#
# Iteration 572 Temperature: 3.218815731417986
# [6, 5, 3]
# [0, 2, 7]
# [4, 1, 8]
# Objective function value: 13
#
# Iteration 573 Temperature: 3.186627574103806
# [6, 5, 3]
# [0, 2, 4]
# [7, 1, 8]
# Objective function value: 11
#
# Iteration 574 Temperature: 3.154761298362768
# [0, 5, 3]
# [6, 2, 4]
# [7, 1, 8]
# Objective function value: 10
#
# Iteration 575 Temperature: 3.1232136853791403
# [0, 2, 3]
# [6, 5, 4]
# [7, 1, 8]
# Objective function value: 8
#
# Iteration 576 Temperature: 3.091981548525349
# [0, 2, 3]
# [6, 5, 8]
# [7, 1, 4]
# Objective function value: 10
#
# Iteration 578 Temperature: 3.0304511157096945
# [6, 2, 3]
# [0, 5, 8]
# [7, 1, 4]
# Objective function value: 11
#
# Iteration 579 Temperature: 3.0001466045525977
# [6, 2, 3]
# [0, 5, 4]
# [7, 1, 8]
# Objective function value: 9
#
# Iteration 580 Temperature: 2.9701451385070716
# [6, 2, 3]
# [0, 5, 4]
# [7, 1, 8]
# Objective function value: 9
#
# Iteration 582 Temperature: 2.9110392502507807
# [8, 2, 3]
# [0, 5, 4]
# [7, 1, 6]
# Objective function value: 9
#
# Iteration 583 Temperature: 2.8819288577482727
# [0, 2, 3]
# [8, 5, 4]
# [7, 1, 6]
# Objective function value: 8
#
# Iteration 584 Temperature: 2.85310956917079
# [0, 4, 3]
# [8, 5, 2]
# [7, 1, 6]
# Objective function value: 10
#
# Iteration 585 Temperature: 2.824578473479082
# [0, 1, 3]
# [8, 5, 2]
# [7, 4, 6]
# Objective function value: 8
#
# Iteration 587 Temperature: 2.768369361856848
# [0, 1, 3]
# [8, 5, 4]
# [7, 2, 6]
# Objective function value: 8
#
# Iteration 590 Temperature: 2.6861460234403376
# [0, 1, 3]
# [8, 5, 4]
# [7, 2, 6]
# Objective function value: 8
#
# Iteration 591 Temperature: 2.6592845632059343
# [0, 1, 3]
# [8, 2, 4]
# [7, 5, 6]
# Objective function value: 8
#
# Iteration 593 Temperature: 2.606364800398136
# [0, 7, 3]
# [8, 2, 4]
# [1, 5, 6]
# Objective function value: 12
#
# Iteration 594 Temperature: 2.5803011523941546
# [0, 7, 3]
# [4, 2, 8]
# [1, 5, 6]
# Objective function value: 10
#
# Iteration 595 Temperature: 2.554498140870213
# [4, 7, 3]
# [0, 2, 8]
# [1, 5, 6]
# Objective function value: 11
#
# Iteration 597 Temperature: 2.5036636278668953
# [4, 7, 5]
# [0, 2, 8]
# [1, 3, 6]
# Objective function value: 15
#
# Iteration 598 Temperature: 2.4786269915882264
# [6, 7, 5]
# [0, 2, 8]
# [1, 3, 4]
# Objective function value: 19
#
# Iteration 599 Temperature: 2.453840721672344
# [6, 7, 5]
# [0, 2, 3]
# [1, 8, 4]
# Objective function value: 15
#
# Iteration 600 Temperature: 2.4293023144556205
# [6, 4, 5]
# [0, 2, 3]
# [1, 8, 7]
# Objective function value: 13
#
# Iteration 601 Temperature: 2.4050092913110643
# [6, 4, 8]
# [0, 2, 3]
# [1, 5, 7]
# Objective function value: 15
#
# Iteration 603 Temperature: 2.3571496064139743
# [6, 4, 8]
# [2, 0, 3]
# [1, 5, 7]
# Objective function value: 16
#
# Iteration 604 Temperature: 2.3335781103498348
# [6, 4, 7]
# [2, 0, 3]
# [1, 5, 8]
# Objective function value: 16
#
# Iteration 605 Temperature: 2.3102423292463365
# [6, 4, 3]
# [2, 0, 7]
# [1, 5, 8]
# Objective function value: 14
#
# Iteration 606 Temperature: 2.287139905953873
# [6, 4, 3]
# [8, 0, 7]
# [1, 5, 2]
# Objective function value: 16
#
# Iteration 607 Temperature: 2.2642685068943345
# [6, 4, 3]
# [8, 0, 7]
# [1, 5, 2]
# Objective function value: 16
#
# Iteration 608 Temperature: 2.2416258218253913
# [6, 4, 3]
# [0, 8, 7]
# [1, 5, 2]
# Objective function value: 15
#
# Iteration 609 Temperature: 2.219209563607137
# [1, 4, 3]
# [0, 8, 7]
# [6, 5, 2]
# Objective function value: 13
#
# Iteration 611 Temperature: 2.175047293291355
# [1, 0, 3]
# [4, 8, 7]
# [6, 5, 2]
# Objective function value: 11
#
# Iteration 612 Temperature: 2.1532968203584413
# [1, 7, 3]
# [4, 8, 0]
# [6, 5, 2]
# Objective function value: 11
#
# Iteration 613 Temperature: 2.1317638521548568
# [7, 1, 3]
# [4, 8, 0]
# [6, 5, 2]
# Objective function value: 11
#
# Iteration 614 Temperature: 2.110446213633308
# [4, 1, 3]
# [7, 8, 0]
# [6, 5, 2]
# Objective function value: 11
#
# Iteration 615 Temperature: 2.089341751496975
# [4, 1, 3]
# [2, 8, 0]
# [6, 5, 7]
# Objective function value: 11
#
# Iteration 616 Temperature: 2.0684483339820052
# [4, 1, 3]
# [2, 8, 0]
# [6, 5, 7]
# Objective function value: 11
#
# Iteration 617 Temperature: 2.0477638506421854
# [2, 1, 3]
# [4, 8, 0]
# [6, 5, 7]
# Objective function value: 9
#
# Iteration 618 Temperature: 2.0272862121357633
# [2, 1, 3]
# [4, 8, 0]
# [6, 7, 5]
# Objective function value: 9
#
# Iteration 621 Temperature: 1.9670737843491188
# [2, 1, 3]
# [4, 8, 0]
# [6, 7, 5]
# Objective function value: 9
#
# Iteration 622 Temperature: 1.9474030465056276
# [2, 1, 3]
# [4, 8, 7]
# [6, 0, 5]
# Objective function value: 11
#
# Iteration 623 Temperature: 1.9279290160405713
# [0, 1, 3]
# [4, 8, 7]
# [6, 2, 5]
# Objective function value: 12
#
# Iteration 624 Temperature: 1.9086497258801656
# [0, 2, 3]
# [4, 8, 7]
# [6, 1, 5]
# Objective function value: 12
#
# Iteration 625 Temperature: 1.889563228621364
# [3, 2, 0]
# [4, 8, 7]
# [6, 1, 5]
# Objective function value: 14
#
# Iteration 626 Temperature: 1.8706675963351502
# [3, 2, 0]
# [4, 5, 7]
# [6, 1, 8]
# Objective function value: 12
#
# Iteration 627 Temperature: 1.8519609203717986
# [3, 2, 0]
# [4, 5, 7]
# [1, 6, 8]
# Objective function value: 10
#
# Iteration 628 Temperature: 1.8334413111680805
# [1, 2, 0]
# [4, 5, 7]
# [3, 6, 8]
# Objective function value: 10
#
# Iteration 633 Temperature: 1.7435844439964543
# [1, 2, 0]
# [4, 7, 5]
# [3, 6, 8]
# Objective function value: 10
#
# Iteration 634 Temperature: 1.7261485995564898
# [1, 2, 0]
# [4, 7, 5]
# [8, 6, 3]
# Objective function value: 8
#
# Iteration 635 Temperature: 1.708887113560925
# [1, 2, 0]
# [4, 7, 5]
# [6, 8, 3]
# Objective function value: 8
#
# Iteration 636 Temperature: 1.6917982424253157
# [1, 2, 0]
# [4, 7, 5]
# [6, 8, 3]
# Objective function value: 8
#
# Iteration 643 Temperature: 1.576866517414586
# [1, 2, 0]
# [4, 7, 5]
# [6, 8, 3]
# Objective function value: 8
#
# Iteration 645 Temperature: 1.5454868737180358
# [1, 2, 0]
# [4, 6, 5]
# [7, 8, 3]
# Objective function value: 4
#
# Iteration 646 Temperature: 1.5300320049808556
# [1, 2, 0]
# [6, 4, 5]
# [7, 8, 3]
# Objective function value: 6
#
# Iteration 650 Temperature: 1.46974263915691
# [1, 2, 0]
# [6, 4, 5]
# [7, 8, 3]
# Objective function value: 6
#
# Iteration 651 Temperature: 1.4550452127653408
# [1, 2, 0]
# [6, 4, 5]
# [8, 7, 3]
# Objective function value: 8
#
# Iteration 654 Temperature: 1.4118289149009975
# [1, 2, 0]
# [6, 4, 3]
# [8, 7, 5]
# Objective function value: 8
#
# Iteration 656 Temperature: 1.3837335194944678
# [1, 0, 2]
# [6, 4, 3]
# [8, 7, 5]
# Objective function value: 9
#
# Iteration 657 Temperature: 1.369896184299523
# [1, 0, 2]
# [6, 4, 3]
# [7, 8, 5]
# Objective function value: 7
#
# Iteration 658 Temperature: 1.3561972224565277
# [1, 0, 2]
# [6, 4, 5]
# [7, 8, 3]
# Objective function value: 7
#
# Iteration 659 Temperature: 1.3426352502319625
# [1, 2, 0]
# [6, 4, 5]
# [7, 8, 3]
# Objective function value: 6
#
# Iteration 660 Temperature: 1.3292088977296428
# [1, 2, 0]
# [6, 4, 5]
# [7, 8, 3]
# Objective function value: 6
#
# Iteration 664 Temperature: 1.276832763615593
# [1, 2, 0]
# [6, 4, 3]
# [7, 8, 5]
# Objective function value: 6
#
# Iteration 665 Temperature: 1.264064435979437
# [1, 2, 0]
# [6, 4, 5]
# [7, 8, 3]
# Objective function value: 6
#
# Iteration 666 Temperature: 1.2514237916196427
# [1, 2, 4]
# [6, 0, 5]
# [7, 8, 3]
# Objective function value: 8
#
# Iteration 667 Temperature: 1.2389095537034462
# [1, 4, 2]
# [6, 0, 5]
# [7, 8, 3]
# Objective function value: 8
#
# Iteration 672 Temperature: 1.178190658298027
# [1, 4, 2]
# [3, 0, 5]
# [7, 8, 6]
# Objective function value: 8
#
# Iteration 673 Temperature: 1.1664087517150468
# [1, 4, 2]
# [3, 6, 5]
# [7, 8, 0]
# Objective function value: 8
#
# Iteration 674 Temperature: 1.1547446641978962
# [1, 4, 2]
# [3, 6, 5]
# [7, 8, 0]
# Objective function value: 8
#
# Iteration 676 Temperature: 1.1317652453803582
# [1, 4, 2]
# [3, 6, 5]
# [8, 7, 0]
# Objective function value: 10
#
# Iteration 679 Temperature: 1.098150685827316
# [1, 4, 2]
# [3, 6, 5]
# [8, 7, 0]
# Objective function value: 10
#
# Iteration 680 Temperature: 1.0871691789690427
# [1, 4, 5]
# [3, 6, 2]
# [8, 7, 0]
# Objective function value: 12
#
# Iteration 681 Temperature: 1.0762974871793523
# [1, 4, 5]
# [2, 6, 3]
# [8, 7, 0]
# Objective function value: 10
#
# Iteration 682 Temperature: 1.0655345123075588
# [1, 4, 2]
# [5, 6, 3]
# [8, 7, 0]
# Objective function value: 8
#
# Iteration 683 Temperature: 1.0548791671844833
# [1, 4, 2]
# [5, 6, 3]
# [8, 7, 0]
# Objective function value: 8
#
# Iteration 684 Temperature: 1.0443303755126385
# [1, 4, 6]
# [5, 2, 3]
# [8, 7, 0]
# Objective function value: 8
#
# Iteration 685 Temperature: 1.0338870717575122
# [1, 4, 3]
# [5, 2, 6]
# [8, 7, 0]
# Objective function value: 6
#
# Iteration 695 Temperature: 0.9350289352808355
# [1, 8, 3]
# [5, 2, 6]
# [4, 7, 0]
# Objective function value: 6
#
# Iteration 698 Temperature: 0.9072576408740594
# [1, 8, 3]
# [4, 2, 6]
# [5, 7, 0]
# Objective function value: 6
#
# Iteration 699 Temperature: 0.8981850644653188
# [1, 5, 3]
# [4, 2, 6]
# [8, 7, 0]
# Objective function value: 4
#
# Iteration 704 Temperature: 0.8541650592753082
# [1, 5, 3]
# [4, 2, 6]
# [8, 7, 0]
# Objective function value: 4
#
# Iteration 712 Temperature: 0.7881762766120003
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 718 Temperature: 0.74205231865899
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 723 Temperature: 0.7056843715499236
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 724 Temperature: 0.6986275278344244
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 734 Temperature: 0.631826213281168
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 735 Temperature: 0.6255079511483562
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 736 Temperature: 0.6192528716368727
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 741 Temperature: 0.5889033192986678
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 742 Temperature: 0.5830142861056811
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 746 Temperature: 0.5600411970061157
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 749 Temperature: 0.543407413413837
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 750 Temperature: 0.5379733392796987
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 758 Temperature: 0.49641204456401333
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 776 Temperature: 0.4142626825382433
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 778 Temperature: 0.4060188551557323
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 796 Temperature: 0.3388283220356684
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 799 Temperature: 0.328764782042887
# [1, 5, 3]
# [4, 2, 6]
# [7, 8, 0]
# Objective function value: 2
#
# Iteration 801 Temperature: 0.32222236288023354
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
# Objective function value: 0
#
# Final Solution:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
# Objective function value: 0
# Heuristic:  Manhatten Tiles + Misplaced Tiles
# Time:  0.8493633270263672
# States Explored:  801
# Temperature Chosen: 1000
# Cooling Rate: 0.99
